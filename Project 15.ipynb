# %% [markdown]
# ## 1) Loading dataset

# %%
import pandas as pd
df = pd.read_csv('ted_data.csv')
df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2  https://ted.com/talks/martin_reeves_how_play_c...
# 3  https://ted.com/talks/james_k_thornton_why_is_...
# 4  https://ted.com/talks/mahendra_singhi_cement_s...

# %% [markdown]
# ## 2) Data Preprocessing

# %%
df.isnull().sum()           # Checking for null values
# Out:
# title     0
# author    1
# date      0
# views     0
# likes     0
# link      0
# dtype: int64

# %%
df = df.dropna()           # Dropping author null value

# %%
df.isnull().sum()
# Out:
# title     0
# author    0
# date      0
# views     0
# likes     0
# link      0
# dtype: int64

# %%
df.info()    # Checking for data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5439 entries, 0 to 5439
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5439 non-null   object
#  1   author  5439 non-null   object
#  2   date    5439 non-null   object
#  3   views   5439 non-null   int64
#  4   likes   5439 non-null   int64
#  5   link    5439 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 297.4+ KB

# %%
df.describe()      # Checking for stats of column
# Out:
#               views         likes
# count  5.439000e+03  5.439000e+03
# mean   2.061955e+06  6.261912e+04
# std    3.567316e+06  1.076533e+05
# min    1.200000e+03  3.700000e+01
# 25%    6.710000e+05  2.000000e+04
# 50%    1.300000e+06  4.100000e+04
# 75%    2.100000e+06  6.500000e+04
# max    7.200000e+07  2.100000e+06

# %% [markdown]
# ## 3) Data Analysis

# %% [markdown]
# ### 1) Finding the most popular Ted talk speaker

# %% [markdown]
# #### 1.1) In terms of number of talks

# %%
speaker_counts = df['author'].value_counts()
top_speaker = speaker_counts.head(5)
for i, (speaker, count) in enumerate(top_speaker.iteritems(),1):
    print(f"Speaker{i}: {speaker}")
    print("No of Talks: ", count)
    print(50*'-')
# Out:
# Speaker1: Alex Gendler
# No of Talks:  45
# --------------------------------------------------
# Speaker2: Iseult Gillespie
# No of Talks:  33
# --------------------------------------------------
# Speaker3: Matt Walker
# No of Talks:  18
# --------------------------------------------------
# Speaker4: Alex Rosenthal
# No of Talks:  15
# --------------------------------------------------
# Speaker5: Elizabeth Cox
# No of Talks:  13
# --------------------------------------------------

# %% [markdown]
# #### 1.2) In terms of no of likes

# %%
speaker_likes = df.groupby('author')['likes'].sum()
top_speaker = speaker_likes.nlargest(5)
for i, (speaker, likes) in enumerate(top_speaker.iteritems(),1):
    print(f"Speaker{i}: {speaker}")
    print("Total Likes: ", likes)
    print(50*'-')
# Out:
# Speaker1: Alex Gendler
# Total Likes:  5691000
# --------------------------------------------------
# Speaker2: Sir Ken Robinson
# Total Likes:  2833600
# --------------------------------------------------
# Speaker3: Bill Gates
# Total Likes:  2349000
# --------------------------------------------------
# Speaker4: Simon Sinek
# Total Likes:  2246000
# --------------------------------------------------
# Speaker5: Brené Brown
# Total Likes:  2204000
# --------------------------------------------------

# %% [markdown]
# #### 1.3) In terms of views

# %%
speaker_views = df.groupby('author')['views'].sum()
top_speaker = speaker_views.nlargest(5)
for i, (speaker, views) in enumerate(top_speaker.iteritems(),1):
    print(f"Speaker{i}: {speaker}")
    print("Total Likes: ", views)
    print(50*'-')
# Out:
# Speaker1: Alex Gendler
# Total Likes:  187196000
# --------------------------------------------------
# Speaker2: Sir Ken Robinson
# Total Likes:  95654000
# --------------------------------------------------
# Speaker3: Bill Gates
# Total Likes:  77800000
# --------------------------------------------------
# Speaker4: Simon Sinek
# Total Likes:  74800000
# --------------------------------------------------
# Speaker5: Brené Brown
# Total Likes:  72000000
# --------------------------------------------------

# %% [markdown]
# ### 2) Month wise Analysis of Ted Talk Frequency

# %%
df['date'] = pd.to_datetime(df['date'], format='%B %Y')  # Extracting month column from date column, where %B %Y means same 
df['month'] = df['date'].dt.strftime('%B')               # date (month) format like in dataset

# %%
talk_per_month = df['month'].value_counts().sort_index()
for month, count in talk_per_month.iteritems():
    print(f" {month} : {count} talks")
# Out:
#  April : 576 talks
#  August : 200 talks
#  December : 334 talks
#  February : 725 talks
#  January : 147 talks
#  July : 446 talks
#  June : 493 talks
#  March : 580 talks
#  May : 322 talks
#  November : 682 talks
#  October : 585 talks
#  September : 349 talks

# %% [markdown]
# ### 3) Year wise Analysis of Ted Talk Frequency

# %%
df['date'] = pd.to_datetime(df['date'], format='%B %Y')  # Extracting month column from date column, where  %B %Y means same 
df['year'] = df['date'].dt.year                          # date (year) format like in dataset

# %%
talk_per_year = df['year'].value_counts().sort_index()
for year, count in talk_per_year.iteritems():
    print(f"  Year {year} : {count} talks")
# Out:
#   Year 1970 : 2 talks
#   Year 1972 : 1 talks
#   Year 1983 : 1 talks
#   Year 1984 : 1 talks
#   Year 1990 : 1 talks
#   Year 1991 : 1 talks
#   Year 1994 : 1 talks
#   Year 1998 : 6 talks
#   Year 2001 : 5 talks
#   Year 2002 : 26 talks
#   Year 2003 : 34 talks
#   Year 2004 : 33 talks
#   Year 2005 : 65 talks
#   Year 2006 : 49 talks
#   Year 2007 : 113 talks
#   Year 2008 : 84 talks
#   Year 2009 : 233 talks
#   Year 2010 : 267 talks
#   Year 2011 : 271 talks
#   Year 2012 : 302 talks
#   Year 2013 : 388 talks
#   Year 2014 : 357 talks
#   Year 2015 : 376 talks
#   Year 2016 : 399 talks
#   Year 2017 : 495 talks
#   Year 2018 : 473 talks
#   Year 2019 : 544 talks
#   Year 2020 : 501 talks
#   Year 2021 : 390 talks
#   Year 2022 : 20 talks

# %% [markdown]
# ### 4) Finding Ted talks of your favourite author

# %%
your_fvrt_author = input('Enter your Favourite author: ').lower()
print('The following are the TED Talks of your favourite author: ')
print('-'*50)
for i in df.values:
    if your_fvrt_author == i[1].lower():
        print('Title : ', i[0])
        print('Author: ', i[1])
        print('Date  : ', i[2])
        print('Views : ', i[3])
        print('Likes : ', i[4])
        print('link  : ', i[5])
        print('-'*50)
# Out:
# Enter your Favourite author: bill gates
# The following are the TED Talks of your favourite author:
# --------------------------------------------------
# Title :  The innovations we need to avoid a climate disaster
# Author:  Bill Gates
# Date  :  2021-03-01 00:00:00
# Views :  1700000
# Likes :  53000
# link  :  https://ted.com/talks/bill_gates_the_innovations_we_need_to_avoid_a_climate_disaster
# --------------------------------------------------
# Title :  How the pandemic will shape the near future
# Author:  Bill Gates
# Date  :  2020-06-01 00:00:00
# Views :  4600000
# Likes :  138000
# link  :  https://ted.com/talks/bill_gates_how_the_pandemic_will_shape_the_near_future
# --------------------------------------------------
# Title :  How we must respond to the coronavirus pandemic
# Author:  Bill Gates
# Date  :  2020-03-01 00:00:00
# Views :  8600000
# Likes :  259000
# link  :  https://ted.com/talks/bill_gates_how_we_must_respond_to_the_coronavirus_pandemic
# --------------------------------------------------
# Title :  The next outbreak? We're not ready
# Author:  Bill Gates
# Date  :  2015-03-01 00:00:00
# Views :  43000000
# Likes :  1300000
# link  :  https://ted.com/talks/bill_gates_the_next_outbreak_we_re_not_ready
# --------------------------------------------------
# Title :  Teachers need real feedback
# Author:  Bill Gates
# Date  :  2013-05-01 00:00:00
# Views :  4500000
# Likes :  135000
# link  :  https://ted.com/talks/bill_gates_teachers_need_real_feedback
# --------------------------------------------------
# Title :  How state budgets are breaking US schools
# Author:  Bill Gates
# Date  :  2011-03-01 00:00:00
# Views :  2100000
# Likes :  63000
# link  :  https://ted.com/talks/bill_gates_how_state_budgets_are_breaking_us_schools
# --------------------------------------------------
# Title :  Innovating to zero!
# Author:  Bill Gates
# Date  :  2010-02-01 00:00:00
# Views :  8100000
# Likes :  245000
# link  :  https://ted.com/talks/bill_gates_innovating_to_zero
# --------------------------------------------------
# Title :  Mosquitos, malaria and education
# Author:  Bill Gates
# Date  :  2009-02-01 00:00:00
# Views :  5200000
# Likes :  156000
# link  :  https://ted.com/talks/bill_gates_mosquitos_malaria_and_education
# --------------------------------------------------

# %% [markdown]
# ### 5) Finding Ted talks with best view to like ratio

# %%
ted_talk ={}

for i in df.values:
    ted_talk[i[0]] = round(i[3]/i[4], 2)

# %%
best_talk = ted_talk.items()
top_talk  = pd.DataFrame(best_talk, columns = ['Title', 'View to Likes ratio'])
top_talk.sort_values(by = 'View to Likes ratio', ascending = False).head(5)
# Out:
#                                                   Title  View to Likes ratio
# 955                A camera that can see around corners                 36.4
# 905                      What's the point(e) of ballet?                 36.4
# 837   How to see more and care less: The art of Geor...                 36.4
# 26    Can you outsmart the fallacy that divided a na...                 36.3
# 1016             The function and fashion of eyeglasses                 36.3

# %% [markdown]
# ### 6) Finding Ted Talks based on tags

# %%
tag = input('Enter a Tag: ').lower()
print('The following are the TED Talks based pn your tag: ')
print(50*'-')  
for i in df.values:
    if tag in i[0].lower():
        print('Title : ', i[0])
        print('Author: ', i[1])
        print('Date  : ', i[2])
        print('Views : ', i[3])
        print('Likes : ', i[4])
        print('link  : ', i[5])
        print(50*'-')
# Out:
# Enter a Tag: climate
# The following are the TED Talks based pn your tag:
# --------------------------------------------------
# Title :  Climate action needs new frontline leadership
# Author:  Ozawa Bineshi Albert
# Date  :  2021-12-01 00:00:00
# Views :  404000
# Likes :  12000
# link  :  https://ted.com/talks/ozawa_bineshi_albert_climate_action_needs_new_frontline_leadership
# --------------------------------------------------
# Title :  Why is China appointing judges to combat climate change?
# Author:  James K. Thornton
# Date  :  2021-10-01 00:00:00
# Views :  427000
# Likes :  12000
# link  :  https://ted.com/talks/james_k_thornton_why_is_china_appointing_judges_to_combat_climate_change
# --------------------------------------------------
# Title :  The ocean's ingenious climate solutions
# Author:  Susan Ruffo
# Date  :  2021-10-01 00:00:00
# Views :  522000
# Likes :  15000
# link  :  https://ted.com/talks/susan_ruffo_the_ocean_s_ingenious_climate_solutions
# --------------------------------------------------
# Title :  How we're reducing the climate impact of electronics
# Author:  Tim Dunn
# Date  :  2022-02-01 00:00:00
# Views :  96000
# Likes :  2900
# link  :  https://ted.com/talks/tim_dunn_how_we_re_reducing_the_climate_impact_of_electronics
# --------------------------------------------------
# Title :  How to boost nature-based solutions to climate change
# Author:  Zac Goldsmith
# Date  :  2021-10-01 00:00:00
# Views :  30000
# Likes :  913
# link  :  https://ted.com/talks/zac_goldsmith_how_to_boost_nature_based_solutions_to_climate_change
# --------------------------------------------------
# Title :  The unexpected, underwater plant fighting climate change
# Author:  Carlos M. Duarte
# Date  :  2021-08-01 00:00:00
# Views :  786000
# Likes :  23000
# link  :  https://ted.com/talks/carlos_m_duarte_the_unexpected_underwater_plant_fighting_climate_change
# --------------------------------------------------
# Title :  Language shouldn't be a barrier to climate action
# Author:  Sophia Kianni
# Date  :  2021-10-01 00:00:00
# Views :  861000
# Likes :  25000
# link  :  https://ted.com/talks/sophia_kianni_language_shouldn_t_be_a_barrier_to_climate_action
# --------------------------------------------------
# Title :  It's time to write a new climate story
# Author:   Countdown
# Date  :  2021-10-01 00:00:00
# Views :  11000
# Likes :  332
# link  :  https://ted.com/talks/countdown_it_s_time_to_write_a_new_climate_story
# --------------------------------------------------
# Title :  Use your voice, vote and wallet for climate action
# Author:  Halla Tómasdóttir
# Date  :  2021-12-01 00:00:00
# Views :  969000
# Likes :  29000
# link  :  https://ted.com/talks/halla_tomasdottir_use_your_voice_vote_and_wallet_for_climate_action
# --------------------------------------------------
# Title :  A next-generation solution to climate crisis
# Author:  Nkosilathi Nyathi
# Date  :  2021-12-01 00:00:00
# Views :  200000
# Likes :  6000
# link  :  https://ted.com/talks/nkosilathi_nyathi_a_next_generation_solution_to_climate_crisis
# --------------------------------------------------
# Title :  Community investment is the missing piece of climate action
# Author:  Dawn Lippert
# Date  :  2021-10-01 00:00:00
# Views :  1000000
# Likes :  32000
# link  :  https://ted.com/talks/dawn_lippert_community_investment_is_the_missing_piece_of_climate_action
# --------------------------------------------------
# Title :  Dear world leaders, these are our climate demands
# Author:  Xiye Bastida, Shiv Soin and Latif Nasser
# Date  :  2021-10-01 00:00:00
# Views :  260000
# Likes :  7800
# link  :  https://ted.com/talks/xiye_bastida_shiv_soin_and_latif_nasser_dear_world_leaders_these_are_our_climate_demands
# --------------------------------------------------
# Title :  An action plan for solving the climate crisis
# Author:  John Doerr and Ryan Panchadsaram
# Date  :  2021-10-01 00:00:00
# Views :  1200000
# Likes :  36000
# link  :  https://ted.com/talks/john_doerr_and_ryan_panchadsaram_an_action_plan_for_solving_the_climate_crisis
# --------------------------------------------------
# Title :  Can climate change ever be funny? 17 comedians try to answer
# Author:  Rainn Wilson
# Date  :  2021-10-01 00:00:00
# Views :  7100
# Likes :  214
# link  :  https://ted.com/talks/rainn_wilson_can_climate_change_ever_be_funny_17_comedians_try_to_answer
# --------------------------------------------------
# Title :  The crucial intersection of climate and capital
# Author:  Nili Gilbert
# Date  :  2021-10-01 00:00:00
# Views :  1200000
# Likes :  37000
# link  :  https://ted.com/talks/nili_gilbert_the_crucial_intersection_of_climate_and_capital
# --------------------------------------------------
# Title :  The powerful women on the front lines of climate action
# Author:  Farwiza Farhan
# Date  :  2021-10-01 00:00:00
# Views :  1000000
# Likes :  32000
# link  :  https://ted.com/talks/farwiza_farhan_the_powerful_women_on_the_front_lines_of_climate_action
# --------------------------------------------------
# Title :  How small countries can make a big impact on climate change
# Author:  Nicola Sturgeon
# Date  :  2021-10-01 00:00:00
# Views :  1200000
# Likes :  38000
# link  :  https://ted.com/talks/nicola_sturgeon_how_small_countries_can_make_a_big_impact_on_climate_change
# --------------------------------------------------
# Title :  How to make radical climate action the new normal
# Author:  Al Gore
# Date  :  2021-10-01 00:00:00
# Views :  1500000
# Likes :  47000
# link  :  https://ted.com/talks/al_gore_how_to_make_radical_climate_action_the_new_normal
# --------------------------------------------------
# Title :  The fastest way to slow climate change now
# Author:  Ilissa Ocko
# Date  :  2021-10-01 00:00:00
# Views :  1500000
# Likes :  46000
# link  :  https://ted.com/talks/ilissa_ocko_the_fastest_way_to_slow_climate_change_now
# --------------------------------------------------
# Title :  Can China achieve its ambitious climate pledges?
# Author:  Hongqiao Liu
# Date  :  2021-10-01 00:00:00
# Views :  1300000
# Likes :  39000
# link  :  https://ted.com/talks/hongqiao_liu_can_china_achieve_its_ambitious_climate_pledges
# --------------------------------------------------
# Title :  The state of the climate crisis in 2021
# Author:  Climate Action Tracker
# Date  :  2021-08-01 00:00:00
# Views :  422000
# Likes :  12000
# link  :  https://ted.com/talks/climate_action_tracker_the_state_of_the_climate_crisis_in_2021
# --------------------------------------------------
# Title :  Remembering climate change ... a message from the year 2071
# Author:  Kim Stanley Robinson
# Date  :  2021-07-01 00:00:00
# Views :  1600000
# Likes :  50000
# link  :  https://ted.com/talks/kim_stanley_robinson_remembering_climate_change_a_message_from_the_year_2071
# --------------------------------------------------
# Title :  What if we saw climate change as an amazing challenge, not a burden?
# Author:  Laura Tenenbaum
# Date  :  2016-05-01 00:00:00
# Views :  47000
# Likes :  1400
# link  :  https://ted.com/talks/laura_tenenbaum_what_if_we_saw_climate_change_as_an_amazing_challenge_not_a_burden
# --------------------------------------------------
# Title :  What to do when climate change feels unstoppable
# Author:  Clover Hogan
# Date  :  2021-02-01 00:00:00
# Views :  1800000
# Likes :  55000
# link  :  https://ted.com/talks/clover_hogan_what_to_do_when_climate_change_feels_unstoppable
# --------------------------------------------------
# Title :  What farmers need to be modern, climate-friendly and profitable
# Author:  Beth Ford
# Date  :  2021-04-01 00:00:00
# Views :  1300000
# Likes :  39000
# link  :  https://ted.com/talks/beth_ford_what_farmers_need_to_be_modern_climate_friendly_and_profitable
# --------------------------------------------------
# Title :  Women and girls, you are part of the climate solution
# Author:  Rumaitha Al Busaidi
# Date  :  2021-05-01 00:00:00
# Views :  1300000
# Likes :  39000
# link  :  https://ted.com/talks/rumaitha_al_busaidi_women_and_girls_you_are_part_of_the_climate_solution
# --------------------------------------------------
# Title :  Cities are driving climate change. Here's how they can fix it
# Author:  Angel Hsu
# Date  :  2020-10-01 00:00:00
# Views :  345000
# Likes :  10000
# link  :  https://ted.com/talks/angel_hsu_cities_are_driving_climate_change_here_s_how_they_can_fix_it
# --------------------------------------------------
# Title :  3 strategies for effectively talking about climate change
# Author:  John Marshall
# Date  :  2021-03-01 00:00:00
# Views :  1200000
# Likes :  37000
# link  :  https://ted.com/talks/john_marshall_3_strategies_for_effectively_talking_about_climate_change
# --------------------------------------------------
# Title :  Earth's original inhabitants — and their role in combating climate change
# Author:  Steven Allison
# Date  :  2020-10-01 00:00:00
# Views :  1200000
# Likes :  38000
# link  :  https://ted.com/talks/steven_allison_earth_s_original_inhabitants_and_their_role_in_combating_climate_change
# --------------------------------------------------
# Title :  How we can curb climate change by spending two percent more on everything
# Author:  Jens Burchardt
# Date  :  2021-04-01 00:00:00
# Views :  1300000
# Likes :  39000
# link  :  https://ted.com/talks/jens_burchardt_how_we_can_curb_climate_change_by_spending_two_percent_more_on_everything
# --------------------------------------------------
# Title :  The innovations we need to avoid a climate disaster
# Author:  Bill Gates
# Date  :  2021-03-01 00:00:00
# Views :  1700000
# Likes :  53000
# link  :  https://ted.com/talks/bill_gates_the_innovations_we_need_to_avoid_a_climate_disaster
# --------------------------------------------------
# Title :  Love, sorrow and the emotions that power climate action
# Author:  Knut Ivar Bjørlykhaug
# Date  :  2020-11-01 00:00:00
# Views :  1300000
# Likes :  39000
# link  :  https://ted.com/talks/knut_ivar_bjorlykhaug_love_sorrow_and_the_emotions_that_power_climate_action
# --------------------------------------------------
# Title :  Climate change is our reality. Here's how we're taking action
# Author:  Al Gore, Gloria Kasang Bulus, Nana Firman, Ximena Loría and Tim Guinee
# Date  :  2020-10-01 00:00:00
# Views :  1200000
# Likes :  37000
# link  :  https://ted.com/talks/al_gore_gloria_kasang_bulus_nana_firman_ximena_loria_and_tim_guinee_climate_change_is_our_reality_here_s_how_we_re_taking_action
# --------------------------------------------------
# Title :  The people who caused the climate crisis aren't the ones who will fix it
# Author:  Angela Mahecha Adrar
# Date  :  2020-12-01 00:00:00
# Views :  1200000
# Likes :  37000
# link  :  https://ted.com/talks/angela_mahecha_adrar_the_people_who_caused_the_climate_crisis_aren_t_the_ones_who_will_fix_it
# --------------------------------------------------
# Title :  Community-powered solutions to the climate crisis
# Author:  Rahwa Ghirmatzion and Zelalem Adefris
# Date  :  2020-10-01 00:00:00
# Views :  1300000
# Likes :  39000
# link  :  https://ted.com/talks/rahwa_ghirmatzion_and_zelalem_adefris_community_powered_solutions_to_the_climate_crisis
# --------------------------------------------------
# Title :  Our moral imperative to act on climate change — and 3 steps we can take (English voiceover)
# Author:  His Holiness Pope Francis
# Date  :  2020-10-01 00:00:00
# Views :  99000
# Likes :  2900
# link  :  https://ted.com/talks/his_holiness_pope_francis_our_moral_imperative_to_act_on_climate_change_and_3_steps_we_can_take_english_voiceover
# --------------------------------------------------
# Title :  How carbon capture networks could help curb climate change
# Author:  Bas Sudmeijer
# Date  :  2020-10-01 00:00:00
# Views :  1300000
# Likes :  39000
# link  :  https://ted.com/talks/bas_sudmeijer_how_carbon_capture_networks_could_help_curb_climate_change
# --------------------------------------------------
# Title :  A chef shares: Here's how we can feed the planet without hurting the climate
# Author:  Peggy Chan
# Date  :  2020-10-01 00:00:00
# Views :  2100
# Likes :  65
# link  :  https://ted.com/talks/peggy_chan_a_chef_shares_here_s_how_we_can_feed_the_planet_without_hurting_the_climate
# --------------------------------------------------
# Title :  To save the climate, we have to reimagine capitalism
# Author:  Rebecca Henderson
# Date  :  2020-10-01 00:00:00
# Views :  1600000
# Likes :  50000
# link  :  https://ted.com/talks/rebecca_henderson_to_save_the_climate_we_have_to_reimagine_capitalism
# --------------------------------------------------
# Title :  The energy Africa needs to develop — and fight climate change
# Author:  Rose M. Mutiso
# Date  :  2020-10-01 00:00:00
# Views :  1400000
# Likes :  44000
# link  :  https://ted.com/talks/rose_m_mutiso_the_energy_africa_needs_to_develop_and_fight_climate_change
# --------------------------------------------------
# Title :  The case for stubborn optimism on climate
# Author:  Christiana Figueres
# Date  :  2020-10-01 00:00:00
# Views :  1300000
# Likes :  41000
# link  :  https://ted.com/talks/christiana_figueres_the_case_for_stubborn_optimism_on_climate
# --------------------------------------------------
# Title :  Climate change is becoming a problem you can taste
# Author:  Amanda Little
# Date  :  2020-10-01 00:00:00
# Views :  1600000
# Likes :  49000
# link  :  https://ted.com/talks/amanda_little_climate_change_is_becoming_a_problem_you_can_taste
# --------------------------------------------------
# Title :  Amazon's climate pledge to be net-zero by 2040
# Author:  Dave Clark and Kara Hurst
# Date  :  2020-10-01 00:00:00
# Views :  1500000
# Likes :  45000
# link  :  https://ted.com/talks/dave_clark_and_kara_hurst_amazon_s_climate_pledge_to_be_net_zero_by_2040
# --------------------------------------------------
# Title :  Make your actions on climate reflect your words
# Author:  Severn Cullis-Suzuki
# Date  :  2020-10-01 00:00:00
# Views :  1500000
# Likes :  46000
# link  :  https://ted.com/talks/severn_cullis_suzuki_make_your_actions_on_climate_reflect_your_words
# --------------------------------------------------
# Title :  Climate justice can't happen without racial justice
# Author:  David Lammy
# Date  :  2020-10-01 00:00:00
# Views :  1600000
# Likes :  48000
# link  :  https://ted.com/talks/david_lammy_climate_justice_can_t_happen_without_racial_justice
# --------------------------------------------------
# Title :  Our moral imperative to act on climate change — and 3 steps we can take
# Author:  His Holiness Pope Francis
# Date  :  2020-10-01 00:00:00
# Views :  1700000
# Likes :  51000
# link  :  https://ted.com/talks/his_holiness_pope_francis_our_moral_imperative_to_act_on_climate_change_and_3_steps_we_can_take
# --------------------------------------------------
# Title :  The state of the climate crisis	in 2020
# Author:  Climate Action Tracker
# Date  :  2020-10-01 00:00:00
# Views :  240000
# Likes :  7200
# link  :  https://ted.com/talks/climate_action_tracker_the_state_of_the_climate_crisis_in_2020
# --------------------------------------------------
# Title :  A game that lets you decide how to tackle the climate crisis
# Author:  Cassie Flynn
# Date  :  2019-09-01 00:00:00
# Views :  2500
# Likes :  75
# link  :  https://ted.com/talks/cassie_flynn_a_game_that_lets_you_decide_how_to_tackle_the_climate_crisis
# --------------------------------------------------
# Title :  How city mayors are taking action on climate change
# Author:  Eric Garcetti
# Date  :  2020-07-01 00:00:00
# Views :  1500000
# Likes :  46000
# link  :  https://ted.com/talks/eric_garcetti_how_city_mayors_are_taking_action_on_climate_change
# --------------------------------------------------
# Title :  The new urgency of climate change
# Author:  Al Gore
# Date  :  2020-06-01 00:00:00
# Views :  2300000
# Likes :  70000
# link  :  https://ted.com/talks/al_gore_the_new_urgency_of_climate_change
# --------------------------------------------------
# Title :  The economic benefits of climate action
# Author:  Marcelo Mena
# Date  :  2020-05-01 00:00:00
# Views :  243000
# Likes :  7200
# link  :  https://ted.com/talks/marcelo_mena_the_economic_benefits_of_climate_action
# --------------------------------------------------
# Title :  The link between climate change, health and poverty
# Author:  Cheryl Holder
# Date  :  2020-03-01 00:00:00
# Views :  291000
# Likes :  8700
# link  :  https://ted.com/talks/cheryl_holder_the_link_between_climate_change_health_and_poverty
# --------------------------------------------------
# Title :  Indigenous knowledge meets science to take on climate change
# Author:  Hindou Oumarou Ibrahim
# Date  :  2019-12-01 00:00:00
# Views :  1200000
# Likes :  37000
# link  :  https://ted.com/talks/hindou_oumarou_ibrahim_indigenous_knowledge_meets_science_to_take_on_climate_change
# --------------------------------------------------
# Title :  How we could change the planet's climate future
# Author:  David Wallace-Wells
# Date  :  2019-09-01 00:00:00
# Views :  2200000
# Likes :  68000
# link  :  https://ted.com/talks/david_wallace_wells_how_we_could_change_the_planet_s_climate_future
# --------------------------------------------------
# Title :  How to turn climate anxiety into action
# Author:  Renée Lertzman
# Date  :  2019-12-01 00:00:00
# Views :  2100000
# Likes :  65000
# link  :  https://ted.com/talks/renee_lertzman_how_to_turn_climate_anxiety_into_action
# --------------------------------------------------
# Title :  What ocean microbes reveal about the changing climate
# Author:  Angelicque White
# Date  :  2019-11-01 00:00:00
# Views :  1900000
# Likes :  57000
# link  :  https://ted.com/talks/angelicque_white_what_ocean_microbes_reveal_about_the_changing_climate
# --------------------------------------------------
# Title :  Climate change will displace millions. Here's how we prepare
# Author:  Colette Pichon Battle
# Date  :  2019-12-01 00:00:00
# Views :  3500000
# Likes :  107000
# link  :  https://ted.com/talks/colette_pichon_battle_climate_change_will_displace_millions_here_s_how_we_prepare
# --------------------------------------------------
# Title :  How we can turn the tide on climate
# Author:  Christiana Figueres and Chris Anderson
# Date  :  2019-12-01 00:00:00
# Views :  2100000
# Likes :  65000
# link  :  https://ted.com/talks/christiana_figueres_and_chris_anderson_how_we_can_turn_the_tide_on_climate
# --------------------------------------------------
# Title :  Why I protest for climate justice
# Author:  Jane Fonda
# Date  :  2019-12-01 00:00:00
# Views :  1900000
# Likes :  57000
# link  :  https://ted.com/talks/jane_fonda_why_i_protest_for_climate_justice
# --------------------------------------------------
# Title :  How climate change could make our food less nutritious
# Author:  Kristie Ebi
# Date  :  2019-04-01 00:00:00
# Views :  2200000
# Likes :  68000
# link  :  https://ted.com/talks/kristie_ebi_how_climate_change_could_make_our_food_less_nutritious
# --------------------------------------------------
# Title :  Why you should be a climate activist
# Author:  Luisa Neubauer
# Date  :  2019-07-01 00:00:00
# Views :  2500000
# Likes :  77000
# link  :  https://ted.com/talks/luisa_neubauer_why_you_should_be_a_climate_activist
# --------------------------------------------------
# Title :  A climate change solution that's right under our feet
# Author:  Asmeret Asefaw Berhe
# Date  :  2019-04-01 00:00:00
# Views :  2000000
# Likes :  60000
# link  :  https://ted.com/talks/asmeret_asefaw_berhe_a_climate_change_solution_that_s_right_under_our_feet
# --------------------------------------------------
# Title :  Emergency medicine for our climate fever
# Author:  Kelly Wanser
# Date  :  2019-07-01 00:00:00
# Views :  1900000
# Likes :  57000
# link  :  https://ted.com/talks/kelly_wanser_emergency_medicine_for_our_climate_fever
# --------------------------------------------------
# Title :  How climate change affects your mental health
# Author:  Britt Wray
# Date  :  2019-05-01 00:00:00
# Views :  2400000
# Likes :  74000
# link  :  https://ted.com/talks/britt_wray_how_climate_change_affects_your_mental_health
# --------------------------------------------------
# Title :  Underwater farms vs. climate change
# Author:  Ayana Elizabeth Johnson and Megan Davis
# Date  :  2019-06-01 00:00:00
# Views :  518000
# Likes :  15000
# link  :  https://ted.com/talks/ayana_elizabeth_johnson_and_megan_davis_underwater_farms_vs_climate_change
# --------------------------------------------------
# Title :  How supercharged plants could slow climate change
# Author:  Joanne Chory
# Date  :  2019-04-01 00:00:00
# Views :  2100000
# Likes :  64000
# link  :  https://ted.com/talks/joanne_chory_how_supercharged_plants_could_slow_climate_change
# --------------------------------------------------
# Title :  An app that predicts the impact of global climate change
# Author:  Sarvesh Subramanian
# Date  :  2019-03-01 00:00:00
# Views :  42000
# Likes :  1200
# link  :  https://ted.com/talks/sarvesh_subramanian_an_app_that_predicts_the_impact_of_global_climate_change
# --------------------------------------------------
# Title :  Visualizing climate change through space and time
# Author:  Peggy Weil
# Date  :  2018-11-01 00:00:00
# Views :  5000
# Likes :  151
# link  :  https://ted.com/talks/peggy_weil_visualizing_climate_change_through_space_and_time
# --------------------------------------------------
# Title :  The disarming case to act right now on climate change
# Author:  Greta Thunberg
# Date  :  2018-11-01 00:00:00
# Views :  6000000
# Likes :  181000
# link  :  https://ted.com/talks/greta_thunberg_the_disarming_case_to_act_right_now_on_climate_change
# --------------------------------------------------
# Title :  The most important thing you can do to fight climate change: talk about it
# Author:  Katharine Hayhoe
# Date  :  2018-11-01 00:00:00
# Views :  3900000
# Likes :  118000
# link  :  https://ted.com/talks/katharine_hayhoe_the_most_important_thing_you_can_do_to_fight_climate_change_talk_about_it
# --------------------------------------------------
# Title :  How China is (and isn't) fighting pollution and climate change
# Author:  Angel Hsu
# Date  :  2018-04-01 00:00:00
# Views :  1900000
# Likes :  57000
# link  :  https://ted.com/talks/angel_hsu_how_china_is_and_isn_t_fighting_pollution_and_climate_change
# --------------------------------------------------
# Title :  How the military fights climate change
# Author:  David Titley
# Date  :  2017-04-01 00:00:00
# Views :  1000000
# Likes :  30000
# link  :  https://ted.com/talks/david_titley_how_the_military_fights_climate_change
# --------------------------------------------------
# Title :  Can we stop climate change by removing CO2 from the air?
# Author:  Tim Kruger
# Date  :  2017-04-01 00:00:00
# Views :  1600000
# Likes :  49000
# link  :  https://ted.com/talks/tim_kruger_can_we_stop_climate_change_by_removing_co2_from_the_air
# --------------------------------------------------
# Title :  Can clouds buy us more time to solve climate change?
# Author:  Kate Marvel
# Date  :  2017-04-01 00:00:00
# Views :  1300000
# Likes :  39000
# link  :  https://ted.com/talks/kate_marvel_can_clouds_buy_us_more_time_to_solve_climate_change
# --------------------------------------------------
# Title :  A climate solution where all sides can win
# Author:  Ted Halstead
# Date  :  2017-04-01 00:00:00
# Views :  1600000
# Likes :  48000
# link  :  https://ted.com/talks/ted_halstead_a_climate_solution_where_all_sides_can_win
# --------------------------------------------------
# Title :  We need nuclear power to solve climate change
# Author:  Joe Lassiter
# Date  :  2016-06-01 00:00:00
# Views :  1200000
# Likes :  36000
# link  :  https://ted.com/talks/joe_lassiter_we_need_nuclear_power_to_solve_climate_change
# --------------------------------------------------
# Title :  A provocative way to finance the fight against climate change
# Author:  Michael Metcalfe
# Date  :  2015-11-01 00:00:00
# Views :  1200000
# Likes :  38000
# link  :  https://ted.com/talks/michael_metcalfe_a_provocative_way_to_finance_the_fight_against_climate_change
# --------------------------------------------------
# Title :  The inside story of the Paris climate agreement
# Author:  Christiana Figueres
# Date  :  2016-02-01 00:00:00
# Views :  1400000
# Likes :  43000
# link  :  https://ted.com/talks/christiana_figueres_the_inside_story_of_the_paris_climate_agreement
# --------------------------------------------------
# Title :  The case for optimism on climate change
# Author:  Al Gore
# Date  :  2016-02-01 00:00:00
# Views :  2200000
# Likes :  68000
# link  :  https://ted.com/talks/al_gore_the_case_for_optimism_on_climate_change
# --------------------------------------------------
# Title :  Climate change is happening. Here's how we adapt
# Author:  Alice Bows-Larkin
# Date  :  2015-06-01 00:00:00
# Views :  1300000
# Likes :  39000
# link  :  https://ted.com/talks/alice_bows_larkin_climate_change_is_happening_here_s_how_we_adapt
# --------------------------------------------------
# Title :  Why climate change is a threat to human rights
# Author:  Mary Robinson
# Date  :  2015-05-01 00:00:00
# Views :  1500000
# Likes :  46000
# link  :  https://ted.com/talks/mary_robinson_why_climate_change_is_a_threat_to_human_rights
# --------------------------------------------------
# Title :  The state of the climate — and what we might do about it
# Author:  Lord Nicholas Stern
# Date  :  2014-09-01 00:00:00
# Views :  877000
# Likes :  26000
# link  :  https://ted.com/talks/lord_nicholas_stern_the_state_of_the_climate_and_what_we_might_do_about_it
# --------------------------------------------------
# Title :  The emergent patterns of climate change
# Author:  Gavin Schmidt
# Date  :  2014-03-01 00:00:00
# Views :  1300000
# Likes :  40000
# link  :  https://ted.com/talks/gavin_schmidt_the_emergent_patterns_of_climate_change
# --------------------------------------------------
# Title :  How to fight desertification and reverse climate change
# Author:  Allan Savory
# Date  :  2013-02-01 00:00:00
# Views :  7900000
# Likes :  238000
# link  :  https://ted.com/talks/allan_savory_how_to_fight_desertification_and_reverse_climate_change
# --------------------------------------------------
# Title :  Let's prepare for our new climate
# Author:  Vicki Arroyo
# Date  :  2012-06-01 00:00:00
# Views :  1200000
# Likes :  36000
# link  :  https://ted.com/talks/vicki_arroyo_let_s_prepare_for_our_new_climate
# --------------------------------------------------
# Title :  Why I must speak out about climate change
# Author:  James Hansen
# Date  :  2012-02-01 00:00:00
# Views :  1600000
# Likes :  48000
# link  :  https://ted.com/talks/james_hansen_why_i_must_speak_out_about_climate_change
# --------------------------------------------------
# Title :  Discovering ancient climates in oceans and ice
# Author:  Rob Dunbar
# Date  :  2010-04-01 00:00:00
# Views :  657000
# Likes :  19000
# link  :  https://ted.com/talks/rob_dunbar_discovering_ancient_climates_in_oceans_and_ice
# --------------------------------------------------
# Title :  The science behind a climate headline
# Author:  Rachel Pike
# Date  :  2009-07-01 00:00:00
# Views :  1000000
# Likes :  31000
# link  :  https://ted.com/talks/rachel_pike_the_science_behind_a_climate_headline
# --------------------------------------------------
# Title :  New thinking on the climate crisis
# Author:  Al Gore
# Date  :  2008-03-01 00:00:00
# Views :  2200000
# Likes :  68000
# link  :  https://ted.com/talks/al_gore_new_thinking_on_the_climate_crisis
# --------------------------------------------------
# Title :  A critical look at geoengineering against climate change
# Author:  David Keith
# Date  :  2007-09-01 00:00:00
# Views :  1400000
# Likes :  44000
# link  :  https://ted.com/talks/david_keith_a_critical_look_at_geoengineering_against_climate_change
# --------------------------------------------------
# Title :  Global priorities bigger than climate change
# Author:  Bjorn Lomborg
# Date  :  2005-02-01 00:00:00
# Views :  1700000
# Likes :  53000
# link  :  https://ted.com/talks/bjorn_lomborg_global_priorities_bigger_than_climate_change
# --------------------------------------------------
# Title :  Averting the climate crisis
# Author:  Al Gore
# Date  :  2006-02-01 00:00:00
# Views :  3600000
# Likes :  109000
# link  :  https://ted.com/talks/al_gore_averting_the_climate_crisis
# --------------------------------------------------
